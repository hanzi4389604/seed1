# %%
# %matplotlib inline
import wandb

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn

import matplotlib.pyplot as plt
import numpy as np
import wandb
wandb.login()
import os
from glob import glob

from torch.utils import data
from torchvision import transforms
from torchvision.datasets.folder import pil_loader


class CustomDataset(data.Dataset):

    def __init__(self, root, train=True, transform=None):
        self.root = root
        self.train = train
        self.transform = transform

        if self.train:
            image_dir = os.path.join(self.root, 'train')
        else:
            image_dir = os.path.join(self.root, 'valid')

        self.paths = glob(os.path.join(image_dir, '*.jpg'))

    def __getitem__(self, index):
        path = self.paths[index]
        img = pil_loader(path)
        target = 0 if 'cat' in path else 1

        if self.transform is not None:
            img = self.transform(img)

        return img, target

    def __len__(self):
        return len(self.paths)


class CustomDataLoader(data.DataLoader):

    def __init__(self, root: str, image_size: int, batch_size: int, train: bool = True, **kwargs):
        transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

        dataset = CustomDataset(root, train=train, transform=transform)
        super(CustomDataLoader, self).__init__(dataset=dataset, batch_size=batch_size, shuffle=True, **kwargs)
####
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.datasets import ImageFolder
train_augs = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize([224,224])])
test_augs = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize([224,224])
])
######
def custom_dataloaders(root='/home/l/20211218 practice/', image_size=1080, batch_size=8, **kwargs):
#    train_loader = CustomDataLoader(root, image_size, batch_size=batch_size, train=True, **kwargs)
#    test_loader = CustomDataLoader(root, image_size, batch_size=batch_size, train=False, **kwargs)

    ######
    train_loader=DataLoader(ImageFolder(os.path.join(root,
            'hotdog1/train1'),transform=train_augs), batch_size,shuffle=True)
    test_loader=DataLoader(ImageFolder(os.path.join(root,
            'hotdog1/test1'),transform=test_augs), batch_size)
    #######
    
    return train_loader, test_loader

# %%
torch.manual_seed(42)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
batch_size = 128
epochs = 300
transform = transforms.Compose(
    [transforms.Resize((224,224)),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


#trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
     #                                   download=True, transform=transform)

#trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
               #                           shuffle=True, num_workers=2)
trainloader=torch.utils.data.DataLoader(ImageFolder(('/home/l/20211218 practice/hotdog1/train'),transform=transform), batch_size, shuffle=True)

valloader=torch.utils.data.DataLoader(ImageFolder(('/home/l/20211218 practice/hotdog1/test'),transform=transform), batch_size, shuffle=True)

#valset = torchvision.datasets.CIFAR10(root='./data', train=False,
#                                       download=True, transform=transform)

#valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
#                                         shuffle=False, num_workers=2)
#trainloader, trainloader = CustomDataset()
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck','horse1', 'ship1', 't1ruck')

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# t1ruck horse1 horse  bird  bird  bird t1ruck horse  deer   dog truck   car truck t1ruck horse1   cat   cat t1ruck  bird  deer t1ruck  bird  bird horse1   cat truck   car ship1 horse1  bird  deer   car plane plane truck   car   dog  deer ship1 horse1   cat horse1  frog ship1 t1ruck  frog truck truck truck  frog horse1   cat horse1  bird   cat  bird truck  bird  bird t1ruck   dog truck  deer   car  ship  frog ship1 ship1  ship t1ruck horse  bird horse ship1  frog  bird horse1 t1ruck ship1 ship1 truck t1ruck t1ruck ship1 t1ruck   cat plane plane  deer horse  ship   dog plane   car  frog  ship t1ruck ship1   cat   cat  ship horse ship1   dog t1ruck truck  frog truck  deer  ship  deer   car   cat ship1   cat plane  deer ship1 horse   cat   dog  bird plane truck horse  bird t1ruck   cat

# %%
# !ls
from swin_transformer1_swin import SwinTransformer
net = SwinTransformer(#img_size=224,
                         #       patch_size=4,
                          #      in_chans=3,
                                num_classes=1000,
                        #        embed_dim=96,
                          #      depths=[2, 2, 6, 2],
                           #     num_heads=[ 3, 6, 12, 24 ],
                                window_size=7,
                                layers=(2, 2, 6, 2),
                                hidden_dim=96,
                                heads=(3, 6, 12, 24),
                             #   mlp_ratio=4.,
                         #       qkv_bias=True,
                        #        qk_scale=True,
                                drop_rate=0.5,
                                drop_path_rate=0.5,
                          #      ape=False,
                            #    patch_norm=True,
                            #    use_checkpoint=True
)
#map_location=torch.device('cpu')


#net.load_state_dict(torch.load('./swin_tiny_patch4_window7_224.pth')['model'],strict=False)
net.head = nn.Linear(net.head.in_features, 13)
#net = nn.Linear(net.in_features, 10)
#net.mlp_head = nn.Linear(net.mlp_head.out_features, 10)
#net.mlp_head = nn.Sequential(
  #  nn.Dropout(p=0.5, inplace=False),
 #   nn.LayerNorm((768,), eps=1e-05, elementwise_affine=True),
 #   nn.Linear(in_features=768, out_features=1000, bias=True),
 #   nn.Dropout(p=0.5, inplace=False),          
 #   nn.LayerNorm((1000,), eps=1e-05, elementwise_affine=True),
 #   nn.Linear(in_features=1000, out_features=10, bias=True)
      
#)
 #   (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
   # (1): Linear(in_features=768, out_features=10, bias=True
#model.classifier = nn.Linear(model.classifier[0].in_features, 4096)
#Linear(in_features=768, out_features=10, bias=True)
#print(model)
#net.mlp_head = nn.Linear(net.mlp_head.in_features, 10)
#dummy_x = torch.randn(1, 3, 224, 224)

#logits = net(dummy_x) 
#net = net.to(device)
#print(logits.shape)
#print(net.head.bias.shape)

dummy_x = torch.randn(1, 3, 224, 224)
dummy_x = dummy_x.to(device)
net = net.to(device)
logits = net(dummy_x)  # (1,3)
print(net)
#print(logits)
print(logits.shape)
# Out:
# configs		      experiments	swin_transformer1_swin.py
# converted	      LICENSE		train-Copy1.py
# converted.zip	      README.md		train.py
# Dockerfile	      requirements.txt	Untitled1.ipynb
# efficientnet	      setup.cfg		Untitled.ipynb
# efficientnet_test.py  swin.ipynb	videometer.ipynb
# [Warning] Fused window process have not been installed. Please refer to get_started.md for installation.
# /home/l/anaconda3/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# SwinTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#   )
#   (pos_drop): Dropout(p=0.5, inplace=False)
# ...
